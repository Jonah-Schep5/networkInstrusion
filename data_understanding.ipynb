# %%
# %run  "./env_setup.py"
# Out:
# /home/rowanm/datasci_business/final_project/networkInstrusion/.env
# User:  rowanm
# Database:  postgresql://rowanm:bestPasswordEver1234@ads1.datasci.vt.edu:5432/ads_db5

# %%
# %%sql
# DO $$
# BEGIN
#     IF EXISTS (
#         SELECT 1
#         FROM information_schema.columns
#         WHERE table_schema = '{username}'
#           AND table_name = 'network_traffic_history'
#           AND column_name = 'flow_type'
#     ) THEN
#         EXECUTE format('ALTER TABLE %I.network_traffic_history RENAME COLUMN flow_type TO attack_state;', '{username}');
#         RAISE NOTICE 'Column renamed from flow_type to attack_state.';
#     ELSE
#         RAISE NOTICE 'Column already renamed or does not exist.';
#     END IF;
# END$$;
# Out:
#  * postgresql://rowanm:***@ads1.datasci.vt.edu:5432/ads_db5
# Done.
# []

# %%
sql = f'''
select * from {username}.NETWORK_TRAFFIC_HISTORY
'''
network_intrusion_full_table = agent.execute_dml(sql)
# Out:
# /home/rowanm/datasci_business/final_project/networkInstrusion/PostgresAgent.py:90: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(network_intrusion_full_table, title="Network Intrusion Data Profiling Report")
profile.to_file("network_profiling_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 22/22 [00:33<00:00,  1.50s/it]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# %%sql
# SELECT *
# FROM {username}.NETWORK_TRAFFIC_HISTORY
# ORDER BY RANDOM()
# LIMIT 10;
# Out:
#  * postgresql://rowanm:***@ads1.datasci.vt.edu:5432/ads_db5
# 10 rows affected.
# [(datetime.datetime(2025, 5, 23, 3, 3, 58), '222.187.194.161', '172.16.173.30', 50397, 25, 'TCP', 17.284574874714153, 53, 37361, 704.9245283018868, 3.0663178229239785, 'ACK', 'SMTP', 'Normal', 1, 'False', 3, 4, 2.161522644948354, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 14, 9, 24, 43), '10.34.77.184', '192.168.85.208', 3239, 53, 'TCP', 2.832411544519312, 49, 31285, 638.469387755102, 17.2997458984428, 'SYN', 'DNS', 'Normal', 1, 'False', 9, 2, 11.045358172097611, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 11, 10, 42, 51), '172.16.150.151', '192.168.91.148', 4016, 1433, 'TCP', 93.79683947561767, 51, 26557, 520.7254901960785, 0.5437283418622795, 'PSH', 'MSSQL', 'Normal', 1, 'True', 10, 6, 0.2831332073497364, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 6, 6, 49, 38), '192.168.96.60', '192.168.118.174', 62870, 80, 'UDP', 7.888268942464821, 51, 50217, 984.6470588235294, 6.465296806179151, 'FIN', 'HTTP', 'Normal', 1, 'False', 6, 1, 6.36603548462546, 207.5343167718111, 1, 6),
#  (datetime.datetime(2025, 5, 4, 13, 51, 23), '10.32.34.46', '10.123.49.250', 39307, 22, 'ICMP', 20.526470735392955, 48, 28937, 602.8541666666666, 2.3384438863732946, 'RST', 'SSH', 'Normal', 1, 'True', 13, 6, 1.409740640416334, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 22, 15, 49, 21), '10.40.207.223', '192.168.163.0', 46980, 3389, 'ICMP', 15.775183667737508, 70, 40758, 582.2571428571429, 4.437349286979139, 'SYN', 'RDP', 'Normal', 1, 'False', 15, 3, 2.5836783176956537, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 27, 3, 43, 32), '192.168.223.204', '192.168.108.79', 16919, 25, 'TCP', 15.935721169196285, 35, 33620, 960.5714285714286, 2.196323569444408, 'SYN', 'SMTP', 'Normal', 1, 'False', 3, 1, 2.1097256687063144, 179.32684983876445, 1, 6),
#  (datetime.datetime(2025, 5, 26, 18, 37, 18), '172.22.68.23', '10.244.158.13', 61446, 53, 'UDP', 28.903425569624392, 46, 36653, 796.804347826087, 1.5915068575242854, 'URG', 'DNS', 'Normal', 1, 'False', 18, 0, 1.2681195836703834, 91.74184802236736, 1, 3),
#  (datetime.datetime(2025, 5, 26, 18, 35, 43), '107.52.134.80', '192.168.88.56', 13639, 25, 'UDP', 6.672295259119774, 50, 19513, 390.26, 7.4936731751580385, 'ACK', 'SMTP', 'Normal', 1, 'False', 18, 0, 2.924480893337176, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 17, 2, 1, 59), '192.168.181.77', '192.168.106.124', 20865, 5432, 'UDP', 2.236090949152767, 41, 30549, 745.0975609756098, 18.335569049878988, 'RST', 'PostgreSQL', 'Normal', 1, 'True', 2, 5, 13.661787778164712, 157.75436182162423, 1, 10)]

# %%
# %%sql
# SELECT * FROM {username}.NETWORK_TRAFFIC_HISTORY ORDER BY packets_per_second DESC LIMIT 10;
# Out:
#  * postgresql://rowanm:***@ads1.datasci.vt.edu:5432/ads_db5
# 10 rows affected.
# [(datetime.datetime(2025, 5, 22, 20, 34, 50), '189.61.153.223', '172.22.255.198', 59026, 80, 'UDP', 0.0010141649586513834, 1035, 32684, 31.578743961352657, 1020544.0359291476, 'URG', 'HTTP', 'DDoS', 4, 'False', 20, 3, 32227.49881189204, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 25, 20, 42, 2), '205.11.255.3', '172.26.30.23', 2113, 443, 'TCP', 0.0010296666593081199, 1038, 19036, 18.339113680154142, 1008093.2412607005, 'ACK', 'HTTPS', 'DDoS', 4, 'True', 20, 6, 18487.536551675043, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 12, 0, 18, 43), '185.144.147.198', '10.213.39.227', 56143, 443, 'ICMP', 0.001039009023458232, 1042, 33032, 31.700575815738965, 1002878.6819692989, 'ACK', 'HTTPS', 'DDoS', 4, 'False', 0, 0, 31791.831691756124, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 6, 8, 41, 1), '54.84.220.41', '192.168.141.160', 48558, 443, 'ICMP', 0.0010125730542595492, 1001, 26107, 26.08091908091908, 988570.6476082241, 'FIN', 'HTTPS', 'DDoS', 4, 'False', 8, 1, 25782.831066041865, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 25, 3, 3, 47), '123.159.18.128', '172.24.127.22', 30764, 443, 'UDP', 0.0010468610583877242, 1032, 36828, 35.68604651162791, 985804.1730861479, 'URG', 'HTTPS', 'DDoS', 4, 'True', 3, 6, 35179.45357210916, 0.0, 1, 1),
#  (datetime.datetime(2025, 6, 1, 8, 16, 33), '202.14.72.4', '10.104.115.254', 55029, 80, 'UDP', 0.00101880412730384, 984, 22120, 22.479674796747968, 965838.2545073256, 'PSH', 'HTTP', 'DDoS', 4, 'True', 8, 6, 21711.729867583374, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 13, 20, 16, 7), '136.65.64.15', '172.18.57.237', 12211, 80, 'UDP', 0.001026028398789752, 980, 30715, 31.341836734693878, 955139.2545819933, 'URG', 'HTTP', 'DDoS', 4, 'False', 20, 1, 29935.818576006048, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 30, 19, 9, 18), '134.179.40.122', '192.168.79.171', 23410, 80, 'ICMP', 0.0010718454709730233, 1020, 24546, 24.064705882352943, 951629.7149383317, 'SYN', 'HTTP', 'DDoS', 4, 'False', 19, 4, 22900.689198898326, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 28, 18, 43, 5), '215.207.196.17', '172.25.8.28', 14907, 80, 'TCP', 0.0010115253247879432, 957, 28943, 30.24346917450366, 946095.9370450029, 'PSH', 'HTTP', 'DDoS', 4, 'False', 18, 2, 28613.223308143697, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 29, 2, 21, 11), '208.212.10.235', '192.168.83.110', 16774, 80, 'UDP', 0.0011101986440314236, 1046, 33158, 31.69980879541109, 942173.7322626323, 'ACK', 'HTTP', 'DDoS', 4, 'False', 2, 3, 29866.72716478429, 0.0, 1, 1)]

# %%
# %%sql
# SELECT * FROM {username}.NETWORK_TRAFFIC_HISTORY WHERE packets_per_second > 1000 ORDER BY packets_per_second ASC LIMIT 40;
# Out:
#  * postgresql://rowanm:***@ads1.datasci.vt.edu:5432/ads_db5
# 40 rows affected.
# [(datetime.datetime(2025, 5, 13, 7, 2, 12), '165.66.191.230', '192.168.26.146', 26313, 30084, 'ICMP', 0.011975433580030018, 12, 596, 49.666666666666664, 1002.0514012963129, 'PSH', 'Unknown', 'Port_Scan', 2, 'False', 7, 1, 49.76855293105021, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 16, 21, 41, 26), '75.39.23.188', '10.50.116.41', 26321, 23998, 'TCP', 0.011866579331678284, 12, 862, 71.83333333333333, 1011.2433974941325, 'RST', 'Unknown', 'Port_Scan', 2, 'False', 21, 4, 72.64098405332851, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 20, 1, 36, 48), '169.172.41.21', '172.25.17.163', 5201, 5699, 'ICMP', 0.01076696044466776, 11, 723, 65.72727272727273, 1021.6439501686524, 'SYN', 'Unknown', 'Port_Scan', 2, 'False', 1, 1, 67.14987054290324, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 19, 6, 26, 59), '148.228.3.142', '192.168.233.219', 29111, 13199, 'TCP', 0.012639762797939316, 13, 715, 55.0, 1028.50031348052, 'URG', 'Unknown', 'Port_Scan', 2, 'False', 6, 0, 56.5675172414286, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 24, 7, 52, 2), '86.118.203.80', '10.16.129.212', 60623, 58772, 'TCP', 0.011424166263725414, 12, 594, 49.5, 1050.404880582227, 'URG', 'Unknown', 'Port_Scan', 2, 'True', 7, 5, 51.995041588820236, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 22, 21, 47, 20), '183.204.212.244', '192.168.175.194', 63856, 7329, 'UDP', 0.010432183171152508, 11, 892, 81.0909090909091, 1054.429338474198, 'SYN', 'Unknown', 'Port_Scan', 2, 'False', 21, 3, 85.5046336289986, 0.0, 1, 1),
#  (datetime.datetime(2025, 5,
 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 11, 19, 54, 41), '12.236.95.202', '172.17.228.52', 13334, 80, 'ICMP', 0.048893881063159714, 939, 28011, 29.830670926517573, 19204.85712285811, 'RST', 'HTTP', 'DDoS', 4, 'True', 19, 6, 572.8937730227673, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 18, 7, 55, 19), '197.191.33.34', '192.168.198.12', 30445, 443, 'UDP', 0.04943816348427597, 950, 26193, 27.571578947368423, 19215.92415750136, 'SYN', 'HTTPS', 'DDoS', 4, 'True', 7, 6, 529.8133699551927, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 14, 6, 47, 33), '145.151.99.89', '192.168.157.197', 1391, 443, 'UDP', 0.049741207410122064, 957, 29103, 30.41065830721003, 19239.581221047236, 'SYN', 'HTTPS', 'DDoS', 4, 'False', 6, 2, 585.0883304870822, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 3, 7, 27, 44), '204.180.186.146', '172.27.3.42', 59139, 443, 'ICMP', 0.04997220810385175, 962, 19579, 20.35239085239085, 19250.700269253284, 'PSH', 'HTTPS', 'DDoS', 4, 'True', 7, 5, 391.79777606206864, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 18, 20, 33, 28), '210.37.101.144', '192.168.97.150', 30406, 80, 'ICMP', 0.04998417286885106, 963, 29622, 30.7601246105919, 19266.098541366853, 'SYN', 'HTTP', 'DDoS', 4, 'True', 20, 6, 592.6275918923872, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 9, 7, 33, 46), '145.194.136.116', '172.30.78.36', 38007, 443, 'ICMP', 0.04956618571929389, 955, 24634, 25.79476439790576, 19267.167447751814, 'SYN', 'HTTPS', 'DDoS', 4, 'False', 7, 4, 496.9920449297573, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 10, 0, 54, 56), '108.120.84.38', '172.19.203.203', 39033, 443, 'UDP', 0.049556077675735374, 956, 31606, 33.06066945606695, 19291.2765666298, 'URG', 'HTTPS', 'DDoS', 4, 'True', 0, 5, 637.7825179549178, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 7, 20, 41, 47), '198.31.222.152', '10.24.160.218', 2952, 80, 'TCP', 0.0488794293948861, 943, 25789, 27.347826086956523, 19292.369237408882, 'FIN', 'HTTP', 'DDoS', 4, 'False', 20, 2, 527.6043587100081, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 3, 20, 12, 20), '58.50.25.207', '172.17.138.42', 27927, 443, 'TCP', 0.04971764223013482, 960, 21893, 22.805208333333333, 19309.041155980754, 'SYN', 'HTTPS', 'DDoS', 4, 'True', 20, 5, 440.3467062790486, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 23, 8, 19, 17), '153.13.168.215', '10.33.84.25', 24312, 443, 'UDP', 0.049498652855682355, 956, 26254, 27.46234309623431, 19313.656935013998, 'FIN', 'HTTPS', 'DDoS', 4, 'False', 8, 4, 530.3982731923196, 0.0, 1, 1),
#  (datetime.datetime(2025, 5, 9, 23, 46, 42), '122.164.137.16', '172.18.163.94', 60499, 443, 'UDP', 0.049233863963468606, 951, 26975, 28.364879074658255, 19315.973263963995, 'ACK', 'HTTPS', 'DDoS', 4, 'False', 23, 4, 547.8952458416707, 0.0, 1, 1)]

# %%
# Out:
#  * postgresql://rowanm:***@ads1.datasci.vt.edu:5432/ads_db5
# Done.
# []
